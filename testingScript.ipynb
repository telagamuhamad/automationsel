# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
import time

EMAIL_ID = "telagamuhamad@gmail.com"

browser = Chrome()
browser.get('https://praktikum-pwl-tiga.herokuapp.com/')
print(browser.title)

#case 1: nama kosong
browser.find_element_by_name("firstName").send_keys("Muhammad Telaga")
time.sleep(2)
browser.find_element_by_name("userEmail").send_keys("telagamuhamad@gmail.com")
time.sleep(2)
browser.find_element_by_name("userPassword").send_keys("Telaga14")
time.sleep(2)
browser.find_element_by_name("confirmPassword").send_keys("Telaga14")
time.sleep(2)
button = browser.find_element_by_tag_name('button')
button.click()
alert_obj = browser.switch_to.alert
time.sleep(2)
alert_obj.accept () 
time.sleep(2)
browser.refresh()

#case 2: email tidak sesuai aturan
browser.find_element_by_name("firstName").send_keys("Muhammad Telaga")
time.sleep(2)
browser.find_element_by_name("userEmail").send_keys("telagamuhamad")
time.sleep(2)
browser.find_element_by_name("userPassword").send_keys("Telaga14")
time.sleep(2)
browser.find_element_by_name("confirmPassword").send_keys("Telaga14")
time.sleep(2)
#memperbaiki penulisan email dengan menambahkan kata "@gmail.com"
browser.find_element_by_name("userEmail").send_keys("@gmail.com")
time.sleep(2)
button = browser.find_element_by_tag_name('button')
button.click()
alert_obj = browser.switch_to.alert
time.sleep(2)
alert_obj.accept () 
time.sleep(2)
browser.refresh()

#case 3: field password tidak sesuai aturan
browser.find_element_by_name("firstName").send_keys("Muhammad Telaga")
time.sleep(2)
browser.find_element_by_name("userEmail").send_keys("telagamuhamad@gmail.com")
time.sleep(2)
browser.find_element_by_name("userPassword").send_keys("telaga14")
time.sleep(2)
#memblok semua teks yang telah diketik dalam field
browser.find_element_by_name("userPassword").send_keys(Keys.CONTROL + "a")
time.sleep(2)
#memencet tombol delete pada keyboard
browser.find_element_by_name("userPassword").send_keys(Keys.DELETE)
time.sleep(2)
#menulis kembali field dengan isi yang benar
browser.find_element_by_name("userPassword").send_keys("Telaga14")
time.sleep(2)
browser.find_element_by_name("confirmPassword").send_keys("Telaga14")
time.sleep(2)
button = browser.find_element_by_tag_name('button')
button.click()
alert_obj = browser.switch_to.alert
time.sleep(2)
alert_obj.accept () 
time.sleep(2)
browser.refresh()

#case 4: field re-password tidak cocok
browser.find_element_by_name("firstName").send_keys("Muhammad Telaga")
time.sleep(2)
browser.find_element_by_name("userEmail").send_keys("telagamuhamad@gmail.com")
time.sleep(2)
browser.find_element_by_name("userPassword").send_keys("Telaga14")
time.sleep(2)
browser.find_element_by_name("confirmPassword").send_keys("telaga14")
time.sleep(2)
#memblok semua teks yang telah diketik dalam field
browser.find_element_by_name("confirmPassword").send_keys(Keys.CONTROL + "a")
time.sleep(2)
#memencet tombol delete pada keyboard
browser.find_element_by_name("confirmPassword").send_keys(Keys.DELETE)
time.sleep(2)
#menulis kembali field dengan isi yang benar
browser.find_element_by_name("confirmPassword").send_keys("Telaga14")
time.sleep(2)
button = browser.find_element_by_tag_name('button')
button.click()
alert_obj = browser.switch_to.alert
time.sleep(2)
alert_obj.accept () 
time.sleep(2)
browser.refresh()

#case 5: semua field lengkap
browser.find_element_by_name("firstName").send_keys("Muhammad Telaga")
time.sleep(2)
browser.find_element_by_name("userEmail").send_keys("telagamuhamad@gmail.com")
time.sleep(2)
browser.find_element_by_name("userPassword").send_keys("Telaga14")
time.sleep(2)
browser.find_element_by_name("confirmPassword").send_keys("Telaga14")
time.sleep(2)
button = browser.find_element_by_tag_name('button')
button.click()
alert_obj = browser.switch_to.alert
time.sleep(2)
alert_obj.accept () 
time.sleep(2)
browser.refresh()
# Out:
# React App
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-2-b6cfe5c06ba4> in <module>
#      85 time.sleep(2)
#      86 #memencet tombol delete pada keyboard
# ---> 87 browser.find_element_by_name("confirmPassword").send_keys(Keys.DELETE)
#      88 time.sleep(2)
#      89 #menulis kembali field dengan isi yang benar
#
# C:\Users\Public\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_name(self, name)
#     494             element = driver.find_element_by_name('foo')
#     495         """
# --> 496         return self.find_element(by=By.NAME, value=name)
#     497
#     498     def find_elements_by_name(self, name):
#
# C:\Users\Public\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
# ...
